# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: PYTHON

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en dos ejercicios de programación libre a completar.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
# ## PARTE I
#
# En este ejercicio debes simular un chatbot al que le haremos pedidos de pizzas.
#
# 1. El chatbot tiene que saludar con un: "Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana ¿Cuántas pizzas  familiares desea?"
# 2. El ususario tiene que introducir un número de pizzas en una variable llamada 'pizz_familiar'
# 3. El chatbot debe responder: "Estupendo, ¿cuántas pizzas medianas desea?" y guardar el número de pizzas medianas en otra variable 'pizz_mediana'
# 4. Además debe responder del chatbot: "Estupendo, se están preparando 'pizz' pizzas familiares y 'pizz_mediana' pizzas medianas. Digame su dirección"
# 5. El ususario tiene que introducir una direccion en formato String en otra variable llamada 'direcc'
# 6. El programa debe calcular el monto total
# 7. Respuesta final del chatbot: "Le mandaremos las '(número total de pizzas)' pizzas a la dirección 'direcc'. Serán <precio total a pagar en euros>. Muchas gracias por su pedido."

# %%
print("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana")
pizz_familiar = int(input("¿Cuántas pizzas familiares desea? "))
pizz_mediana = int(input("Estupendo, ¿cuántas pizzas medianas desea? "))
#print(f"Estupendo, se están preparando {pizz_familiar} pizzas familiares y {pizz_mediana} pizzas medianas.")
direcc = input(f"Estupendo, se están preparando {pizz_familiar} pizzas familiares y {pizz_mediana} pizzas medianas. Digame su dirección ")
monto = round(8.95*pizz_familiar + 9.90*pizz_mediana, 2)
print(f"Le mandaremos las {pizz_familiar + pizz_mediana} pizzas a la dirección {direcc}. Serán {monto}. Muchas gracias por su pedido.")
# Out:
# Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana
# ¿Cuántas pizzas familiares desea? 4
# Estupendo, ¿cuántas pizzas medianas desea? 2
# Estupendo, se están preparando 4 pizzas familiares y 2 pizzas medianas. Digame su dirección Juncal 1461
# Le mandaremos las 6 pizzas a la dirección Juncal 1461. Serán 55.6. Muchas gracias por su pedido.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
# ## Parte II
#
# Crea un programa que realice las siguientes acciones:
#
# 1. Solicite al usuario que introduzca 3 números enteros separados por comas (por ejemplo: 1,2,3).
# 2. Convierta esa entrada en una lista de números enteros.
# 3. Utilizando funciones built-in, determine el número máximo, el número mínimo y la suma total de los números introducidos.
# 4. Determine la verdad o falsedad de la siguiente afirmación: "El número máximo menos el número mínimo es igual a la suma total dividida por 5".
# 5. Muestre los resultados utilizando print.

# %%
lista = input("Introduzca 3 números enteros separados por comas: ").split(",")

for i in range(len(lista)):
    lista[i] = int(lista[i])

#lista = [int(num) for num in lista]

print(lista, type(lista))

for num in lista:
    if type(num) == int:
        print(f"El numero {num} es entero")

maximo = max(lista)
minimo = min(lista)
suma = sum(lista)
print("Maximo: ", maximo, type(maximo))
print("Minimo: ", minimo, type(minimo))
print("Suma: ", suma, type(suma))
print("El número máximo menos el número mínimo es igual a la suma total dividida por 5: ", maximo - minimo == suma/5)
# Out:
# Introduzca 3 números enteros separados por comas: 15,5,30
# [15, 5, 30] <class 'list'>
# El numero 15 es entero
# El numero 5 es entero
# El numero 30 es entero
# Maximo:  30 <class 'int'>
# Minimo:  5 <class 'int'>
# Suma:  50 <class 'int'>
# El número máximo menos el número mínimo es igual a la suma total dividida por 5:  False
